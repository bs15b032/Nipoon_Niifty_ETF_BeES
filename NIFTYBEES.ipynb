# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
NIFTYBEES10=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS10.csv')
NIFTYBEES10
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2009-01-01  29.900000  31.500000  27.040001  28.969000  28.969000
# 1   2009-02-01  28.850000  29.900000  27.021000  28.016001  28.016001
# 2   2009-03-01  27.110001  31.379999  25.690001  30.306000  30.306000
# 3   2009-04-01  30.410000  35.305000  29.815001  34.849998  34.849998
# 4   2009-05-01  35.220001  46.000000  35.200001  44.606998  44.606998
# 5   2009-06-01  45.299999  47.125000  40.000000  43.540001  43.540001
# 6   2009-07-01  43.700001  46.599998  39.299999  46.138000  46.138000
# 7   2009-08-01  46.250000  50.000000  43.700001  46.744999  46.744999
# 8   2009-09-01  47.000000  50.580002  45.605000  50.477001  50.477001
# 9   2009-10-01  50.599998  51.549999  47.395000  47.558998  47.558998
# 10  2009-11-01  47.305000  51.439999  45.904999  50.312000  50.312000
# 11  2009-12-01  50.779999  52.380001  49.688999  52.171001  52.171001
# ...

# %%
NIFTYBEES10['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES10['Close'].plot(label='CLOSE price')
NIFTYBEES10['High'].plot(label='High price')
NIFTYBEES10['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2009-2010 prices')

plt.ylabel('Nifty ETF prices')
plt.show()

# %%
NIFTYBEES2010_Return_percentage=((NIFTYBEES10["Adj Close"][11]-NIFTYBEES10["Adj Close"][0])*100)/NIFTYBEES10["Adj Close"][0]
NIFTYBEES2010_Return_percentage
# Out:
# 80.09251613794054

# %%
NIFTYBEES11=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS11.csv')
NIFTYBEES11
NIFTYBEES11['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES11['Close'].plot(label='CLOSE price')
NIFTYBEES11['High'].plot(label='High price')
NIFTYBEES11['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2010-2011 prices')

plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2011_Return_percentage=(NIFTYBEES11["Adj Close"][11]-NIFTYBEES11["Adj Close"][0])/NIFTYBEES11["Adj Close"][0]
NIFTYBEES2011_Return_percentage
# Out:
# 0.24519571385451253

# %%
NIFTYBEES11
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2010-01-01  52.171001  58.000000  48.000000  49.695000  49.695000
# 1   2010-02-01  49.689999  54.500000  47.505001  49.299999  49.299999
# 2   2010-03-01  49.299999  54.000000  40.985001  52.605000  52.605000
# 3   2010-04-01  53.014999  54.500000  50.110001  52.404999  52.404999
# 4   2010-05-01  52.200001  58.099998  48.799999  50.630001  50.630001
# 5   2010-06-01  50.744999  53.990002  50.000000  53.275002  53.275002
# 6   2010-07-01  52.115002  55.900002  51.814999  54.189999  54.189999
# 7   2010-08-01  54.000000  56.299999  50.099998  54.455002  54.455002
# 8   2010-09-01  55.000000  61.215000  50.599998  60.150002  60.150002
# 9   2010-10-01  61.000000  63.500000  52.500000  60.798000  60.798000
# 10  2010-11-01  61.900002  64.000000  57.904999  59.604000  59.604000
# 11  2010-12-01  60.000000  61.980000  57.700001  61.880001  61.880001
# ...

# %%
NIFTYBEES12=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS12.csv')
NIFTYBEES12
NIFTYBEES12['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES12['Close'].plot(label='CLOSE price')
NIFTYBEES12['High'].plot(label='High price')
NIFTYBEES12['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2011-2012 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2012_Return_percentage=(NIFTYBEES12["Adj Close"][11]-NIFTYBEES12["Adj Close"][0])/NIFTYBEES12["Adj Close"][0]
NIFTYBEES2012_Return_percentage
# Out:
# -0.15257442403862448

# %%
NIFTYBEES13=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS13.csv')
NIFTYBEES13
NIFTYBEES13['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES13['Close'].plot(label='CLOSE price')
NIFTYBEES13['High'].plot(label='High price')
NIFTYBEES13['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2012-2013 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2013_Return_percentage=(NIFTYBEES13["Adj Close"][11]-NIFTYBEES13["Adj Close"][0])/NIFTYBEES13["Adj Close"][0]
NIFTYBEES2013_Return_percentage
# Out:
# 0.13883109951260564

# %%
NIFTYBEES14=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS14.csv')
NIFTYBEES14
NIFTYBEES14['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES14['Close'].plot(label='CLOSE price')
NIFTYBEES14['High'].plot(label='High price')
NIFTYBEES14['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2013-2014 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2014_Return_percentage=((NIFTYBEES14["Adj Close"][11]-NIFTYBEES14["Adj Close"][0])*100)/NIFTYBEES14["Adj Close"][0]
NIFTYBEES2014_Return_percentage
# Out:
# 4.193698007746745

# %%
NIFTYBEES15=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS15.csv')
NIFTYBEES15
NIFTYBEES15['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES15['Close'].plot(label='CLOSE price')
NIFTYBEES15['High'].plot(label='High price')
NIFTYBEES15['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2014-2015 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2015_Return_percentage=(NIFTYBEES15["Adj Close"][11]-NIFTYBEES15["Adj Close"][0])/NIFTYBEES15["Adj Close"][0]
NIFTYBEES2015_Return_percentage
# Out:
# 0.35890415979042445

# %%
NIFTYBEES16=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS16.csv')
NIFTYBEES16
NIFTYBEES16['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES16['Close'].plot(label='CLOSE price')
NIFTYBEES16['High'].plot(label='High price')
NIFTYBEES16['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2015-2016 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2016_Return_percentage=(NIFTYBEES16["Adj Close"][11]-NIFTYBEES16["Adj Close"][0])/NIFTYBEES16["Adj Close"][0]
NIFTYBEES2016_Return_percentage
# Out:
# -0.10260162708474047

# %%
NIFTYBEES17=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS17.csv')
NIFTYBEES17
NIFTYBEES17['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES17['Close'].plot(label='CLOSE price')
NIFTYBEES17['High'].plot(label='High price')
NIFTYBEES17['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2016-2017 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2017_Return_percentage=(NIFTYBEES17["Adj Close"][11]-NIFTYBEES17["Adj Close"][0])/NIFTYBEES17["Adj Close"][0]
NIFTYBEES2017_Return_percentage
# Out:
# 9.52393758406578

# %%
NIFTYBEES18=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS18.csv')
NIFTYBEES18
NIFTYBEES18['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES18['Close'].plot(label='CLOSE price')
NIFTYBEES18['High'].plot(label='High price')
NIFTYBEES18['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2017-2018 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2018_Return_percentage=(NIFTYBEES18["Adj Close"][11]-NIFTYBEES18["Adj Close"][0])/NIFTYBEES18["Adj Close"][0]
NIFTYBEES2018_Return_percentage
# Out:
# 0.2432705293003575

# %%
NIFTYBEES19=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS19.csv')
NIFTYBEES19
NIFTYBEES19['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES19['Close'].plot(label='CLOSE price')
NIFTYBEES19['High'].plot(label='High price')
NIFTYBEES19['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2018-2019 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2019_Return_percentage=(NIFTYBEES19["Adj Close"][11]-NIFTYBEES19["Adj Close"][0])/NIFTYBEES19["Adj Close"][0]
NIFTYBEES2019_Return_percentage
# Out:
# 0.0011537729968450763

# %%
NIFTYBEES20=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS20.csv')
NIFTYBEES20
NIFTYBEES20['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES20['Close'].plot(label='CLOSE price')
NIFTYBEES20['High'].plot(label='High price')
NIFTYBEES20['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2019-2020 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2020_Return_percentage=((NIFTYBEES20["Adj Close"][11]-NIFTYBEES20["Adj Close"][0])*100)/NIFTYBEES20["Adj Close"][0]
NIFTYBEES2020_Return_percentage
# Out:
# 13.819626262333733

# %%
NIFTYBEES21=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS21.csv')
NIFTYBEES21
NIFTYBEES21['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES21['Close'].plot(label='CLOSE price')
NIFTYBEES21['High'].plot(label='High price')
NIFTYBEES21['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2020Adj Close-2021 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2021_Return_percentage=(NIFTYBEES21["Adj Close"][11]-NIFTYBEES21["Adj Close"][0])/NIFTYBEES21["Adj Close"][0]
NIFTYBEES2021_Return_percentage
# Out:
# 0.17221050046725642

# %%
NIFTYBEES22=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS22.csv')
NIFTYBEES22
NIFTYBEES22['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES22['Close'].plot(label='CLOSE price')
NIFTYBEES22['High'].plot(label='High price')
NIFTYBEES22['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2021-2022 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2022_Return_percentage=(NIFTYBEES22["Adj Close"][11]-NIFTYBEES22["Adj Close"][0])/NIFTYBEES22["Adj Close"][0]
NIFTYBEES2022_Return_percentage
# Out:
# 0.2853523975899084

# %%
NIFTYBEES23=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS23.csv')
NIFTYBEES23
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-01-01  190.000000  223.000000  182.699997  187.630005  187.630005
# 1  2022-02-01  190.800003  199.850006  176.100006  181.839996  181.839996
# 2  2022-03-01  181.839996  198.000000  170.259995  188.869995  188.869995
# 3  2022-04-01  189.940002  210.000000  182.199997  185.429993  185.429993
# 4  2022-05-01  176.250000  194.479996  153.300003  179.869995  179.869995
# 5  2022-06-01  180.190002  184.990005  165.699997  169.710007  169.710007
# 6  2022-06-27  171.000000  173.899994  171.000000  172.619995  172.619995
#
#      Volume
# 0  56503820
# 1  77560444
# 2  91275857
# 3  79849068
# 4  90906043
# 5  73994489
# 6   3875168

# %%
NIFTYBEES23=pd.read_csv(r'C:\Users\vs786\OneDrive\Desktop\NIFTYBEES.NS\NIFTYBEES.NS23.csv')
NIFTYBEES23
NIFTYBEES23['Open'].plot(label='OPEN price',figsize=(17,7))
NIFTYBEES23['Close'].plot(label='CLOSE price')
NIFTYBEES23['High'].plot(label='High price')
NIFTYBEES23['Low'].plot(label='Low price')
plt.legend()
plt.title('Nipoon BeES Nifty ETF 2022-2023 prices')
plt.ylabel('Nifty ETF prices')
plt.show()
NIFTYBEES2023_Return_percentage=(NIFTYBEES23["Adj Close"][6]-NIFTYBEES23["Adj Close"][0])/NIFTYBEES23["Adj Close"][0]
NIFTYBEES2023_Return_percentage
# Out:
# -0.07999791930933446

# %%
NIFTYBEES2009_To_2022_Return_percentage=(NIFTYBEES23["Adj Close"][6]-NIFTYBEES10["Adj Close"][0])/NIFTYBEES10["Open"][0]
NIFTYBEES2009_To_2022_Return_percentage
# Out:
# 4.80438110367893

# %%
NIFTYBEES2017Return_percentage=(NIFTYBEES17['Adj Close'][0]/NIFTYBEES17['Adj Close'][11])-1
NIFTYBEES2017Return_percentage
# Out:
# -0.08695758931015074

# %%
Total_13_Year_return=(1+NIFTYBEES2009_To_2022_Return_percentage)**(1/13)
Total_13_Year_return=(Total_return-1)*100
Total_13_Year_return
# Out:
# 14.485492131249277

# %%
NIFTYBEES17
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2016-01-01  80.199997  80.750000  73.500000  76.228996  76.228996
# 1   2016-02-01  76.400002  76.699997  69.459999  70.837997  70.837997
# 2   2016-03-01  71.035004  80.000000  71.035004  79.126999  79.126999
# 3   2016-04-01  79.000000  80.830002  76.000000  79.516998  79.516998
# 4   2016-05-01  79.300003  83.099998  78.000000  82.667999  82.667999
# 5   2016-06-01  82.699997  84.449997  80.949997  84.288002  84.288002
# 6   2016-07-01  84.500000  88.279999  84.300003  88.111000  88.111000
# 7   2016-08-01  88.102997  89.750000  84.430000  89.616997  89.616997
# 8   2016-09-01  89.750000  91.500000  87.500000  87.858002  87.858002
# 9   2016-10-01  88.098999  91.870003  86.800003  88.179001  88.179001
# 10  2016-11-01  88.099998  94.989998  66.280998  83.917999  83.917999
# 11  2016-12-01  84.000000  84.349998  80.654999  83.488998  83.488998
# ...

# %%
# Out:
# 4
